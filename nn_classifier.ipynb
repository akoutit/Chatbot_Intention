# %%
import pandas as pd
import numpy as np
import torch
from transformers import CamembertTokenizer, CamembertForSequenceClassification
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F

# Charger les données

file_path = "/content/intent-detection-extended-v2.csv"
df = pd.read_csv(file_path)

# ✅ Encoder toutes les classes, y compris "out_scope"
label_encoder = LabelEncoder()
df["label_encoded"] = label_encoder.fit_transform(df["label"])
num_classes = len(label_encoder.classes_)

# ✅ Split équilibré des classes avec StratifiedShuffleSplit
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_idx, test_idx in splitter.split(df["text"], df["label_encoded"]):
    X_train, X_test = df["text"].iloc[train_idx], df["text"].iloc[test_idx]
    y_train, y_test = df["label_encoded"].iloc[train_idx], df["label_encoded"].iloc[test_idx]

# Initialiser le tokenizer
tokenizer = CamembertTokenizer.from_pretrained("camembert-base")

# Définition du dataset
class IntentDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=128):
        self.texts = texts.tolist()
        self.labels = labels.tolist()
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        encoding = self.tokenizer(
            self.texts[idx], truncation=True, padding="max_length", max_length=self.max_length, return_tensors="pt"
        )
        return {
            "input_ids": encoding["input_ids"].squeeze(0),
            "attention_mask": encoding["attention_mask"].squeeze(0),
            "labels": torch.tensor(self.labels[idx], dtype=torch.long),
        }

# Créer les datasets et dataloaders
dev = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train_dataset = IntentDataset(X_train, y_train, tokenizer)
test_dataset = IntentDataset(X_test, y_test, tokenizer)
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

# Charger le modèle Camembert
model = CamembertForSequenceClassification.from_pretrained("camembert-base", num_labels=num_classes).to(dev)
optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)

# ✅ Entraînement avec Early Stopping
def train(model, train_loader, optimizer, epochs=300, patience=10):
    model.train()
    best_loss = float("inf")
    patience_counter = 0

    for epoch in range(epochs):
        total_loss = 0
        for batch in train_loader:
            optimizer.zero_grad()
            input_ids = batch["input_ids"].to(dev)
            attention_mask = batch["attention_mask"].to(dev)
            labels = batch["labels"].to(dev)
            outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
            loss = outputs.loss
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}")

        # 🔹 Early Stopping: Vérifier si la perte a diminué
        if avg_loss < best_loss:
            best_loss = avg_loss
            patience_counter = 0  # Réinitialiser le compteur
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping déclenché")
                break  # Arrêter l'entraînement si la perte ne diminue plus

train(model, train_loader, optimizer)

# Évaluation
def evaluate(model, test_loader):
    model.eval()
    predictions, true_labels = [], []
    with torch.no_grad():
        for batch in test_loader:
            input_ids = batch["input_ids"].to(dev)
            attention_mask = batch["attention_mask"].to(dev)
            labels = batch["labels"].to(dev)
            outputs = model(input_ids, attention_mask=attention_mask)
            logits = outputs.logits
            preds = torch.argmax(F.softmax(logits, dim=1), axis=1)
            predictions.extend(preds.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())

    print("Accuracy:", accuracy_score(true_labels, predictions))
    print(classification_report(true_labels, predictions, target_names=label_encoder.classes_))

evaluate(model, test_loader)

# ✅ Fonction de prédiction avec gestion de "out_scope"
def predict_with_threshold(text, threshold=0.5):
    model.eval()
    encoding = tokenizer(text, truncation=True, padding="max_length", max_length=128, return_tensors="pt")
    input_ids = encoding["input_ids"].to(dev)
    attention_mask = encoding["attention_mask"].to(dev)

    with torch.no_grad():
        logits = model(input_ids, attention_mask=attention_mask).logits
        probs = F.softmax(logits, dim=1).cpu().numpy()[0]
        max_prob = np.max(probs)
        predicted_label = np.argmax(probs)

        # 🔹 Si aucune classe n'a une forte probabilité, renvoyer "out_scope"
        if max_prob < threshold:
            return "out_scope"

        return label_encoder.inverse_transform([predicted_label])[0]

# Exemple de test
texte_test = "Quel est le statut de ma commande ?"
print("Prédiction :", predict_with_threshold(texte_test))
# Out:
# Some weights of CamembertForSequenceClassification were not initialized from the model checkpoint at camembert-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1, Loss: 2.1981
# Epoch 2, Loss: 2.1386
# Epoch 3, Loss: 2.0868
# Epoch 4, Loss: 2.0157
# Epoch 5, Loss: 1.8966
# Epoch 6, Loss: 1.7688
# Epoch 7, Loss: 1.6412
# Epoch 8, Loss: 1.5140
# Epoch 9, Loss: 1.3739
# Epoch 10, Loss: 1.2779
# Epoch 11, Loss: 1.1552
# Epoch 12, Loss: 1.0763
# Epoch 13, Loss: 0.9767
# Epoch 14, Loss: 0.8877
# Epoch 15, Loss: 0.8372
# Epoch 16, Loss: 0.7686
# Epoch 17, Loss: 0.7200
# Epoch 18, Loss: 0.6404
# Epoch 19, Loss: 0.5937
# Epoch 20, Loss: 0.5495
# Epoch 21, Loss: 0.5022
# Epoch 22, Loss: 0.4657
# Epoch 23, Loss: 0.4512
# Epoch 24, Loss: 0.3990
# Epoch 25, Loss: 0.3858
# Epoch 26, Loss: 0.3496
# Epoch 27, Loss: 0.3222
# Epoch 28, Loss: 0.3041
# Epoch 29, Loss: 0.3028
# Epoch 30, Loss: 0.2710
# Epoch 31, Loss: 0.2448
# Epoch 32, Loss: 0.2533
# Epoch 33, Loss: 0.2181
# Epoch 34, Loss: 0.2027
# Epoch 35, Loss: 0.1896
# Epoch 36, Loss: 0.1752
# Epoch 37, Loss: 0.1675
# Epoch 38, Loss: 0.1558
# Epoch 39, Loss: 0.1484
# Epoch 40, Loss: 0.1384
# Epoch 41, Loss: 0.1343
# Epoch 42, Loss: 0.1273
# Epoch 43, Loss: 0.1181
# Epoch 44, Loss: 0.1149
# Epoch 45, Loss: 0.1080
# Epoch 46, Loss: 0.1055
# Epoch 47, Loss: 0.0980
# Epoch 48, Loss: 0.0933
# Epoch 49, Loss: 0.0875
# Epoch 50, Loss: 0.0858
# Epoch 51, Loss: 0.0814
# Epoch 52, Loss: 0.0774
# Epoch 53, Loss: 0.0771
# Epoch 54, Loss: 0.0709
# Epoch 55, Loss: 0.0685
# Epoch 56, Loss: 0.0680
# Epoch 57, Loss: 0.0637
# Epoch 58, Loss: 0.0625
# Epoch 59, Loss: 0.0596
# Epoch 60, Loss: 0.0561
# Epoch 61, Loss: 0.0544
# Epoch 62, Loss: 0.0529
# Epoch 63, Loss: 0.0519
# Epoch 64, Loss: 0.0505
# Epoch 65, Loss: 0.0471
# Epoch 66, Loss: 0.0459
# Epoch 67, Loss: 0.0436
# Epoch 68, Loss: 0.0442
# Epoch 69, Loss: 0.0425
# Epoch 70, Loss: 0.0404
# Epoch 71, Loss: 0.0392
# Epoch 72, Loss: 0.0377
# Epoch 73, Loss: 0.0378
# Epoch 74, Loss: 0.0349
# Epoch 75, Loss: 0.0354
# Epoch 76, Loss: 0.0342
# Epoch 77, Loss: 0.0328
# Epoch 78, Loss: 0.0321
# Epoch 79, Loss: 0.0302
# Epoch 80, Loss: 0.0306
# Epoch 81, Loss: 0.0293
# Epoch 82, Loss: 0.0285
# Epoch 83, Loss: 0.0281
# Epoch 84, Loss: 0.0276
# Epoch 85, Loss: 0.0265
# Epoch 86, Loss: 0.0256
# Epoch 87, Loss: 0.0257
# Epoch 88, Loss: 0.0247
# Epoch 89, Loss: 0.0234
# Epoch 90, Loss: 0.0235
# Epoch 91, Loss: 0.0224
# Epoch 92, Loss: 0.0230
# Epoch 93, Loss: 0.0214
# Epoch 94, Loss: 0.0209
# Epoch 95, Loss: 0.0206
# Epoch 96, Loss: 0.0210
# Epoch 97, Loss: 0.0199
# Epoch 98, Loss: 0.0192
# Epoch 99, Loss: 0.0188
# Epoch 100, Loss: 0.0188
# Epoch 101, Loss: 0.0179
# Epoch 102, Loss: 0.0178
# Epoch 103, Loss: 0.0171
# Epoch 104, Loss: 0.0169
# Epoch 105, Loss: 0.0161
# Epoch 106, Loss: 0.0159
# Epoch 107, Loss: 0.0159
# Epoch 108, Loss: 0.0154
# Epoch 109, Loss: 0.0150
# Epoch 110, Loss: 0.0147
# Epoch 111, Loss: 0.0146
# Epoch 112, Loss: 0.0141
# Epoch 113, Loss: 0.0142
# Epoch 114, Loss: 0.0136
# Epoch 115, Loss: 0.0135
# Epoch 116, Loss: 0.0137
# Epoch 117, Loss: 0.0126
# Epoch 118, Loss: 0.0127
# Epoch 119, Loss: 0.0121
# Epoch 120, Loss: 0.0119
# Epoch 121, Loss: 0.0120
# Epoch 122, Loss: 0.0115
# Epoch 123, Loss: 0.0113
# Epoch 124, Loss: 0.0119
# Epoch 125, Loss: 0.0117
# Epoch 126, Loss: 0.0112
# Epoch 127, Loss: 0.0111
# Epoch 128, Loss: 0.0103
# Epoch 129, Loss: 0.0107
# Epoch 130, Loss: 0.0099
# Epoch 131, Loss: 0.0100
# Epoch 132, Loss: 0.0100
# Epoch 133, Loss: 0.0099
# Epoch 134, Loss: 0.0095
# Epoch 135, Loss: 0.0094
# Epoch 136, Loss: 0.0098
# Epoch 137, Loss: 0.0091
# Epoch 138, Loss: 0.0091
# Epoch 139, Loss: 0.0084
# Epoch 140, Loss: 0.0087
# Epoch 141, Loss: 0.0086
# Epoch 142, Loss: 0.0086
# Epoch 143, Loss: 0.0083
# Epoch 144, Loss: 0.0080
# Epoch 145, Loss: 0.0081
# Epoch 146, Loss: 0.0078
# Epoch 147, Loss: 0.0077
# Epoch 148, Loss: 0.0074
# Epoch 149, Loss: 0.0074
# Epoch 150, Loss: 0.0073
# Epoch 151, Loss: 0.0073
# Epoch 152, Loss: 0.0072
# Epoch 153, Loss: 0.0071
# Epoch 154, Loss: 0.0069
# Epoch 155, Loss: 0.0068
# Epoch 156, Loss: 0.0064
# Epoch 157, Loss: 0.0064
# Epoch 158, Loss: 0.0065
# Epoch 159, Loss: 0.0063
# Epoch 160, Loss: 0.0061
# Epoch 161, Loss: 0.0064
# Epoch 162, Loss: 0.0063
# Epoch 163, Loss: 0.0064
# Epoch 164, Loss: 0.0059
# Epoch 165, Loss: 0.0058
# Epoch 166, Loss: 0.0057
# Epoch 167, Loss: 0.0059
# Epoch 168, Loss: 0.0059
# Epoch 169, Loss: 0.0054
# Epoch 170, Loss: 0.0053
# Epoch 171, Loss: 0.0055
# Epoch 172, Loss: 0.0053
# Epoch 173, Loss: 0.0051
# Epoch 174, Loss: 0.0049
# Epoch 175, Loss: 0.0051
# Epoch 176, Loss: 0.0049
# Epoch 177, Loss: 0.0048
# Epoch 178, Loss: 0.0050
# Epoch 179, Loss: 0.0049
# Epoch 180, Loss: 0.0046
# Epoch 181, Loss: 0.0047
# Epoch 182, Loss: 0.0047
# Epoch 183, Loss: 0.0046
# Epoch 184, Loss: 0.0045
# Epoch 185, Loss: 0.0044
# Epoch 186, Loss: 0.0044
# Epoch 187, Loss: 0.0044
# Epoch 188, Loss: 0.0043
# Epoch 189, Loss: 0.0044
# Epoch 190, Loss: 0.0041
# Epoch 191, Loss: 0.0043
# Epoch 192, Loss: 0.0041
# Epoch 193, Loss: 0.0041
# Epoch 194, Loss: 0.0040
# Epoch 195, Loss: 0.0039
# Epoch 196, Loss: 0.0039
# Epoch 197, Loss: 0.0037
# Epoch 198, Loss: 0.0040
# Epoch 199, Loss: 0.0041
# Epoch 200, Loss: 0.0040
# Epoch 201, Loss: 0.0038
# Epoch 202, Loss: 0.0040
# Epoch 203, Loss: 0.0664
# Epoch 204, Loss: 0.0047
# Epoch 205, Loss: 0.0960
# Epoch 206, Loss: 0.0501
# Epoch 207, Loss: 0.0061
# Early stopping déclenché
# Accuracy: 0.8928571428571429
#                    precision    recall  f1-score   support
#
#       book_flight       1.00      1.00      1.00         2
#        book_hotel       0.75      1.00      0.86         3
#          carry_on       1.00      1.00      1.00         3
#     flight_status       1.00      1.00      1.00         3
#      lost_luggage       1.00      1.00      1.00         3
#      out_of_scope       0.80      0.67      0.73         6
#         translate       1.00      1.00      1.00         3
#      travel_alert       1.00      1.00      1.00         2
# travel_suggestion       0.67      0.67      0.67         3
#
#          accuracy                           0.89        28
#         macro avg       0.91      0.93      0.92        28
#      weighted avg       0.89      0.89      0.89        28
#
# Prédiction : out_of_scope

# %%
texte_test = "où je dois mettre mon baggage?"
print("Prédiction :", predict_with_threshold(texte_test))
# Out:
# Prédiction : lost_luggage

# %%
texte_test = "souhaite une recommandation de voyage"
print("Prédiction :", predict_with_threshold(texte_test))
# Out:
# Prédiction : travel_suggestion

# %%
model.save_pretrained("saved_model")
tokenizer.save_pretrained("saved_model")
# Out:
# ('saved_model/tokenizer_config.json',
#  'saved_model/special_tokens_map.json',
#  'saved_model/sentencepiece.bpe.model',
#  'saved_model/added_tokens.json')
